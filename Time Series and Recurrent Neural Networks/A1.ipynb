# %%
# %%capture
import pandas as pd

# !gdown --id 1eAozcrUavrJhJaYorEfgM4kOUuupaigg
# !gdown --id 1erAYxYR9zgP7uxRXqiDNkI6toxI5csz3
# !gdown --id 1eFtpCkvynYxrJQCiv4GRyafVKW5jjgl2
# !gdown --id 1eY0xfNWCmXa02AhbO54-H8KiaaqdpRXv
# !gdown --id 1dwbKbwuCUP2NscgyGjXgm8NwLAKMY0R4
# !gdown --id 1eWoCxEeRfZVZy0xkN4B17T5TmAuUjd9E
# !gdown --id 1eZfGrV_HoRiVC5ZjsXBGhpbOs1Gc6iRR
# !gdown --id 1f2Feut0NO0DeeVUNwF6JRDc9_Qy5dxxA
# !gdown --id 1e9Ke0kzz-WYJuyiMVE5yBUyLLUd5hsuv
# !gdown --id 1f37l9ZZt1SRNxQ7tfWtwY1hbrFKv81A8

# %%
import csv
sniffer = csv.Sniffer()
for i in range(1, 11):
  if f'd{i}.csv' == 'd3.csv' or f'd{i}.csv' == 'd4.csv' or f'd{i}.csv' == 'd7.csv':
    with open(f'd{i}.tsv') as f:
      print(f)
  else:
    with open(f'd{i}.csv') as f:
      dialect = csv.Sniffer().sniff(f.read())
      f.seek(0)
      print(f, dialect.delimiter)
# Out:
# <_io.TextIOWrapper name='d1.csv' mode='r' encoding='UTF-8'> ;
# <_io.TextIOWrapper name='d2.csv' mode='r' encoding='UTF-8'> ,
# <_io.TextIOWrapper name='d3.tsv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='d4.tsv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='d5.csv' mode='r' encoding='UTF-8'> ,
# <_io.TextIOWrapper name='d6.csv' mode='r' encoding='UTF-8'> ,
# <_io.TextIOWrapper name='d7.tsv' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='d8.csv' mode='r' encoding='UTF-8'> ,
# <_io.TextIOWrapper name='d9.csv' mode='r' encoding='UTF-8'> ,
# <_io.TextIOWrapper name='d10.csv' mode='r' encoding='UTF-8'> ,

# %%
df1 = pd.read_csv('d1.csv', sep = None, engine = "python")
df1.head()
# Out:
#             ﻿CITY STATE  CAPITAL  ...    MAC  WAL-MART  POST_OFFICES
# 0       São Paulo    SP        1  ...  130.0       7.0         225.0
# 1          Osasco    SP        0  ...    7.0       1.0          10.0
# 2  Rio De Janeiro    RJ        1  ...   68.0       1.0         120.0
# 3        Brasília    DF        1  ...   28.0       1.0          60.0
# 4    Porto Alegre    RS        1  ...   19.0      12.0          53.0
#
# [5 rows x 81 columns]

# %%
df2 = pd.read_csv('d2.csv')
df2.head()
# Out:
#      Date  StockPrice
# 0  1/1/70   83.368095
# 1  2/1/70   81.591053
# 2  3/1/70   81.338095
# 3  4/1/70   76.805909
# 4  5/1/70   69.278571

# %%
df3 = pd.read_csv('d3.tsv', sep = '\t')
df3.sort_values(by = 'ESTADO')
# Out:
#         Unnamed: 0 DATA INICIAL  ... MÊS   ANO
# 25603        25603   2005-05-22  ...   5  2005
# 101001      101001   2018-09-30  ...   9  2018
# 17719        17719   2008-05-25  ...   5  2008
# 73469        73469   2015-03-29  ...   3  2015
# 51281        51281   2009-11-29  ...  11  2009
# ...            ...          ...  ...  ..   ...
# 4550          4550   2007-08-12  ...   8  2007
# 10949        10949   2012-03-11  ...   3  2012
# 13784        13784   2005-07-24  ...   7  2005
# 73423        73423   2015-03-22  ...   3  2015
# 46589        46589   2006-07-16  ...   7  2006
#
# [106823 rows x 21 columns]

# %%
df4 = pd.read_csv('d4.tsv' , sep = '\t')
df4.head()
# Out:
#   unit,sector,na_item,geo\time      2020   ...      1996       1995
# 0           MIO_EUR,S1,B1GQ,AT  375562.0   ...  186968.1   184351.3
# 1           MIO_EUR,S1,B1GQ,BE  451176.9   ...  219965.3   220251.5
# 2           MIO_EUR,S1,B1GQ,BG   60642.7   ...    9829.9    14512.8
# 3           MIO_EUR,S1,B1GQ,CY   21000.3   ...    7890.1     7596.0
# 4           MIO_EUR,S1,B1GQ,CZ  213661.0   ...   53088.1    46008.4
#
# [5 rows x 27 columns]

# %%
df5 = pd.read_csv('d5.csv')
df5.head()
# Out:
#    longitude  latitude  ...  median_house_value  ocean_proximity
# 0    -122.23     37.88  ...            452600.0         NEAR BAY
# 1    -122.22     37.86  ...            358500.0         NEAR BAY
# 2    -122.24     37.85  ...            352100.0         NEAR BAY
# 3    -122.25     37.85  ...            341300.0         NEAR BAY
# 4    -122.25     37.85  ...            342200.0         NEAR BAY
#
# [5 rows x 10 columns]

# %%
df6 = pd.read_csv('d6.csv')
df6.head()
# Out:
#    comprimento-sepala  largura-sepala  ...  largura-petala        label
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
df7 = pd.read_csv('d7.tsv', sep = '\t')
df7.head()
# Out:
#   unit,indx,coicop,geo\time 2021M07  2021M06   ... 2005M03  2005M02  2005M01
# 0         I15,ACPI,CP011,AT       :        :   ...   87.2 e   87.4 e   88.4 e
# 1         I15,ACPI,CP011,BE       :        :   ...   97.2 e   96.5 e   95.0 e
# 2         I15,ACPI,CP011,BG       :        :   ...   67.5 e   69.6 e   72.1 e
# 3         I15,ACPI,CP011,CY       :        :   ...  108.5 e  117.7 e  117.8 e
# 4         I15,ACPI,CP011,CZ       :        :   ...   80.8 e   81.8 e   83.8 e
#
# [5 rows x 200 columns]

# %%
df8 = pd.read_csv('d8.csv')
df8.head()
# Out:
#      Date  StockPrice
# 0  3/1/09   46.884545
# 1  3/1/84   47.303636
# 2  8/1/93   47.713182
# 3  9/1/93   47.883333
# 4  4/1/84   47.908000

# %%
df9 = pd.read_csv('d9.csv')
df9.head()
# Out:
#    Unnamed: 0                      Created At  ... Unnamed: 23  Unnamed: 24
# 0           0  Sun Jan 08 01:22:05 +0000 2017  ...         NaN          NaN
# 1           1  Sun Jan 08 01:49:01 +0000 2017  ...         NaN          NaN
# 2           2  Sun Jan 08 01:01:46 +0000 2017  ...         NaN          NaN
# 3           3  Wed Jan 04 21:43:51 +0000 2017  ...         NaN          NaN
# 4           4  Mon Jan 09 15:08:21 +0000 2017  ...         NaN          NaN
#
# [5 rows x 26 columns]

# %%
df10 = pd.read_csv('d10.csv')
df10.head()
# Out:
#          Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0  2013-03-01    Uluru     19.7  ...     28.4         No            No
# 1  2013-03-02    Uluru     21.6  ...     31.3         No            No
# 2  2013-03-03    Uluru     21.3  ...     34.5         No            No
# 3  2013-03-04    Uluru     22.9  ...     35.4         No            No
# 4  2013-03-05    Uluru     24.0  ...     37.3         No            No
#
# [5 rows x 23 columns]
